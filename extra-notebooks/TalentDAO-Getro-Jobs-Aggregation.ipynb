# %%
import pandas as pd
import glob
import os

path = r'D:\GitHub\crypto-jobs-scraper\node-scraper\data'
all_files = glob.glob(os.path.join(path , "*.csv"))

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame
# Out:
#             Company Name                                           Job Link  \
# 0                   Wyre  https://angel.co/company/sendwyre/jobs/2154498...
# 1               Coinbase  https://www.coinbase.com/careers/4178971?gh_ji...
# 2               Coinbase  https://www.coinbase.com/careers/4178128?gh_ji...
# 3               Coinbase  https://www.coinbase.com/careers/4176153?gh_ji...
# 4               Coinbase  https://www.coinbase.com/careers/3667448?gh_ji...
# ...                  ...                                                ...
# 11888           Coinbase  https://www.coinbase.com/careers/1445686?gh_ji...
# 11889         Oasis Labs  https://boards.greenhouse.io/oasislabs/jobs/40...
# 11890         Oasis Labs  https://boards.greenhouse.io/oasislabs/jobs/40...
# 11891           CoinList  https://boards.greenhouse.io/coinlist/jobs/403...
# 11892  Polychain Capital  https://boards.greenhouse.io/polychaincapital/...
#
#                  Job Location  \
# 0               United States
# 1               United States
# 2                   Singapore
# 3                       India
# 4               United States
# ...                       ...
# 11888           United States
# 11889                     NaN
# 11890           United States
# 11891  San Francisco, CA, USA
# 11892  San Francisco, CA, USA
#
#                                              Job Title  Salary Range  \
# 0                      Director of Customer Experience           NaN
# 1            Technical Program Manager, Cloud Security           NaN
# 2       Sr. Associate, Web3 Ecosystem (Southeast Asia)           NaN
# 3                     Senior Site Reliability Engineer           NaN
# 4                   Process Owner (Content Moderation)           NaN
# ...                                                ...           ...
# 11888  Technical Sourcer - Product and Design (Remote)           NaN
# 11889                            Sr. Software Engineer           NaN
# 11890                        Business Development Lead           NaN
# 11891                                Software Engineer           NaN
# 11892                        Cryptocurrency Researcher           NaN
#
#                                                 Tags Posted Before  \
# 0      Sales & Business Development:Customer Service           19h
# 1                                      IT:Operations           20h
# 2                                                NaN           20h
# 3                               Software Engineering           20h
# 4                                                NaN           20h
# ...                                              ...           ...
# 11888                              Product:IT:Design           3yr
# 11889                           Software Engineering           3yr
# 11890                   Sales & Business Development           3yr
# 11891                           Software Engineering           3yr
# 11892                                            NaN           4yr
#
#                                     Source URL         Source Name  \
# 0      https://jobs.blockchaincapital.com/jobs  Blockchain Capital
# 1      https://jobs.blockchaincapital.com/jobs  Blockchain Capital
# 2      https://jobs.blockchaincapital.com/jobs  Blockchain Capital
# 3      https://jobs.blockchaincapital.com/jobs  Blockchain Capital
# 4      https://jobs.blockchaincapital.com/jobs  Blockchain Capital
# ...                                        ...                 ...
# 11888      https://jobs.polychain.capital/jobs   Polychain Capital
# 11889      https://jobs.polychain.capital/jobs   Polychain Capital
# 11890      https://jobs.polychain.capital/jobs   Polychain Capital
# 11891      https://jobs.polychain.capital/jobs   Polychain Capital
# 11892      https://jobs.polychain.capital/jobs   Polychain Capital
#
#        Getro ObjectID
# 0            13089590
# 1            13085604
# 2            13085602
# 3            13085601
# 4            13085600
# ...               ...
# 11888          556067
# 11889          550410
# 11890          550393
# 11891          550355
# 11892          428686
#
# [11893 rows x 10 columns]

# %%
deduplicated = (frame.drop_duplicates(subset='Job Link', keep='first', inplace=False)
                .drop_duplicates(subset='Getro ObjectID', keep='first', inplace=False))

# %%
frame.shape
# Out:
# (11893, 10)

# %%
deduplicated.shape
# Out:
# (7085, 10)

# %%
header = ["Company Name", "Job Link", "Job Location", "Job Title", "Salary Range", "Tags", "Posted Before"]
deduplicated.to_csv(r'D:\GitHub\crypto-jobs-scraper\data\getro\all_jobs.csv', columns = header, index=False)
